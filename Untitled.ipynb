# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/79828/django/project/uxuidesigner/designer/data/vacancies_2024.csv")
# Out:
# C:\Users\79828\AppData\Local\Temp\ipykernel_15072\1694278925.py:1: DtypeWarning: Columns (1,2,3,7,8,9,10,12,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Users/79828/django/project/uxuidesigner/designer/data/vacancies_2024.csv")

# %%
df = df.drop(['Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'], )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df = df.drop(['Unnamed: 7',	'Unnamed: 8',	'Unnamed: 9',	'Unnamed: 10',	'Unnamed: 11',	'Unnamed: 12',	'Unnamed: 13',	'Unnamed: 14',	'Unnamed: 15'], )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
df
# Out:
#                                                   name  \
# 0                        SAP R/3 functional consultant
# 1                        Broadcast encryption engineer
# 2                      Embedded OS engineering manager
# 3        Coordinator on Intellectual Property Projects
# 4                     Outsourcing Projects Coordinator
# ...                                                ...
# 1048570                            QA manager/director
# 1048571                                      Senior QA
# 1048572                         Web admin (Cloud Team)
# 1048573                                Visual designer
# 1048574                        Системный администратор
#
#                                            key_skills salary_from salary_to  \
# 0        C, С++, Python, Linux, Microsoft Office, SQL         NaN       NaN
# 1        C, С++, Python, Linux, Microsoft Office, SQL         NaN    2000.0
# ...
