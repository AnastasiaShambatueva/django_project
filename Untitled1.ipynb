# %%
import pandas as pd

# %%
df_1 = pd.read_csv("C:/Users/79828/django/project/uxuidesigner/designer/data/IT_vacancies_full.csv")

# %%
df_1 = df_1.drop(['Published at'], axis = 1)

# %%
df_2 = pd.read_csv("C:/Users/79828/django/project/uxuidesigner/designer/data/vacancies_2024.csv", low_memory=False)

# %%
df_2
# Out:
#                                                   name  \
# 0                        SAP R/3 functional consultant
# 1                        Broadcast encryption engineer
# 2                      Embedded OS engineering manager
# 3        Coordinator on Intellectual Property Projects
# 4                     Outsourcing Projects Coordinator
# ...                                                ...
# 1048570                            QA manager/director
# 1048571                                      Senior QA
# 1048572                         Web admin (Cloud Team)
# 1048573                                Visual designer
# 1048574                        Системный администратор
#
#                                            key_skills salary_from salary_to  \
# 0        C, С++, Python, Linux, Microsoft Office, SQL         NaN       NaN
# 1        C, С++, Python, Linux, Microsoft Office, SQL         NaN    2000.0
# ...

# %%
df_1['Published at'] = df_2['published_at']

# %%
df_1
# Out:
#             Ids                                        Employer  \
# 0      49313809                                        Space307
# 1      48813842                                       Монополия
# 2      49413720                                    Eden Springs
# 3      46460892                                     Импорт Хоум
# 4      49555567                              Pride Games Studio
# ...         ...                                             ...
# 48559  49108967                                    A-N SECURITY
# 48560  49108929  Филиал ФКУ Налог-Сервис ФНС России в г. Москве
# 48561  47462568                                  Market Warrior
# 48562  48713091                                        Кон.Трол
# 48563  49108761                                     Vivid Money
#
#                                                     Name  Salary      From  \
# 0                                Golang Developer (Кипр)    True  251322.0
# ...

# %%
df_1.to_csv('vacansies.csv', index=False)

# %%
from IPython.display import FileLink
FileLink('vacansies.csv').html = FileLink('vacansies.csv').html.replace(
    'download', 'download.csv'
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 2
#       1 from IPython.display import FileLink
# ----> 2 FileLink('vacansies.csv').html = FileLink('vacansies.csv').html.replace(
#       3     'download', 'download.csv'
#       4 )
#
# AttributeError: 'FileLink' object has no attribute 'html'

# %%
from IPython.display import FileDownload
FileDownload('vacancies.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 from IPython.display import FileDownload
#       2 FileDownload('vacancies.csv')
#
# ImportError: cannot import name 'FileDownload' from 'IPython.display' (C:\Users\79828\anaconda3\Lib\site-packages\IPython\display.py)
